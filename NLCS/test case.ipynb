# %%
pip install sacrebleu transformers sentencepiece evaluate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from transformers import AutoModel

model_name = "choidf/kde4-en-vi-test"

model = AutoModel.from_pretrained(model_name)
# Out:
# Some weights of the model checkpoint at choidf/kde4-en-vi-test were not used when initializing MarianModel: ['final_logits_bias', 'lm_head.weight']
# - This IS expected if you are initializing MarianModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing MarianModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
from transformers import pipeline

translator = pipeline("translation", model="choidf/kde4-en-vi-test")
translator("That's my CD.")
# Out:
# [{'translation_text': 'CD của tôi.'}]

# %%
from transformers import pipeline

translator = pipeline("translation", model="choidf/kde4-en-vi-test")
translator("I'm at a loss for words.")
# Out:
# [{'translation_text': 'Tôi không biết phải nói gì.'}]

# %%
from transformers import pipeline

translator = pipeline("translation", model="choidf/kde4-en-vi-test")
translator("Tom assumed Mary would be late.")
# Out:
# [{'translation_text': 'Tom giả định là Ma- ri sẽ về trễ.'}]

# %%
from transformers import pipeline

translator = pipeline("translation", model="choidf/kde4-en-vi-test")
translator("I'm economically independent of my parents.")
# Out:
# [{'translation_text': 'Tôi độc lập về mặt kinh tế với bố mẹ.'}]

# %%
from transformers import pipeline

translator = pipeline("translation", model="choidf/kde4-en-vi-test")
translator("The poem.")
# Out:
# [{'translation_text': 'Description'}]

# %%
from transformers import pipeline

translator = pipeline("translation", model="choidf/kde4-en-vi-test")
translator("The people crowded round the injured man, but they made way for the doctor when he reached the scene of the accident.")
# Out:
# [{'translation_text': 'Dân chúng đông đảo quanh người đàn ông bị thương, nhưng họ đã tìm cách cho y sĩ khi ông tới cảnh xảy ra sự cố.'}]

# %%
from transformers import pipeline

translator = pipeline("translation", model="choidf/kde4-en-vi-test")
translator("Text generation is the task of generating text with the goal of appearing indistinguishable to human-written text.")
# Out:
# [{'translation_text': 'Thế hệ văn bản là nhiệm vụ tạo ra văn bản với mục tiêu xuất hiện không thể phân biệt chữ viết con người.'}]

# %%
from transformers import pipeline

translator = pipeline("translation", model="choidf/kde4-en-vi-test")
translator("Many participants threw their economic, industrial, and scientific capabilities behind this total war, blurring the distinction between civilian and military resources.")
# Out:
# [{'translation_text': 'Nhiều người tham gia đã bỏ qua các khả năng kinh tế, công nghiệp và khoa học nằm sau toàn bộ cuộc chiến này, làm mờ đi sự khác biệt giữa các nguồn lực thường dân và quân sự.'}]

# %%
from transformers import pipeline

translator = pipeline("translation", model="choidf/kde4-en-vi-test")
translator("VnExpress provides latest Vietnam news, regional, business, financial, industries, travel news and views to policy makers, professionals, tourists.")
# Out:
# [{'translation_text': 'Vnaxpress cung cấp tin tức Việt Nam mới nhất, khu vực, thương mại, tài chính, công nghiệp, thông tin và quan điểm của các nhà hoạch định chính sách, nghề nghiệp, du khách.'}]
